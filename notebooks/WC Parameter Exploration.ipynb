# %%
# change to the root directory of the project
import os
if os.getcwd().split("/")[-1] == "examples":
    os.chdir('..')
   
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    import sys
    # !{sys.executable} -m pip install matplotlib
    import matplotlib.pyplot as plt
    
import numpy as np

from neurolib.models.wc import WCModel
from neurolib.utils.parameterSpace import ParameterSpace
from neurolib.optimize.exploration import BoxSearch

# a nice color map
plt.rcParams['image.cmap'] = 'plasma'

# %%
wc = WCModel()

# %%
wc.params['exc_ext'] = 0.0
wc.params['c_excinh'] = 15.0
wc.params['duration'] = 200

parameters = ParameterSpace({"exc_ext":  np.linspace(0.7, 2.6, 50), "c_excinh": np.linspace(9.3, 15, 50)})
# info: chose np.linspace(0, 3, 21) or more, values here are low for testing
search = BoxSearch(wc, parameters)
# Out:
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/exploration.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/parameter.py:897: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   if np.issubdtype(dtype, np.str):
# MainProcess root INFO     Number of parameter configurations: 500
# MainProcess root INFO     BoxSearch: Environment initialized.

# %%
search.run()
# Out:
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2022-03-14-21H-01M-33S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2022-03-14-21H-01M-33S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2022-03-14-21H-01M-33S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2022-03-14-21H-01M-33S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2022-03-14-21H-01M-33S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 4 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished   0/500 runs [                    ]  0.0%
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished  25/500 runs [=                   ]  5.0%, remaining: 0:03:29
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished  50/500 runs [==                  ] 10.0%, remaining: 0:03:20
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished  75/500 runs [===                 ] 15.0%, remaining: 0:03:13
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished 100/500 runs [====                ] 20.0%, remaining: 0:03:00
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished 125/500 runs [=====               ] 25.0%, remaining: 0:02:52
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished 150/500 runs [======              ] 30.0%, remaining: 0:02:39
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
# ...
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished 225/500 runs [=========           ] 45.0%, remaining: 0:02:10
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet INFO     PROGRESS: Finished 250/500 runs [==========          ] 50.0%, remaining: 0:01:58
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):

# %%
search.loadResults()
print("Number of results: {}".format(len(search.results)))
# Out:
# MainProcess root INFO     Loading results from ./data/hdf/exploration.hdf
# MainProcess root INFO     Analyzing trajectory results-2022-03-13-18H-05M-05S
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/exploration.hdf`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading trajectory `results-2022-03-13-18H-05M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `config` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `parameters` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `results` in mode `1`.
# MainProcess root INFO     Creating `dfResults` dataframe ...
# MainProcess root INFO     Loading all results to `results` dictionary ...
# 100%|██████████| 2500/2500 [00:19<00:00, 127.28it/s]
# MainProcess root INFO     Aggregating results to `dfResults` ...
# 100%|██████████| 2500/2500 [00:03<00:00, 821.98it/s]
# MainProcess root INFO     All results loaded.
# Number of results: 2500

# %%
for i in search.dfResults.index:
    search.dfResults.loc[i, 'max_exc'] = np.max(search.results[i]['exc'][:, -int(1000/wc.params['dt']):])

# %%
import neurolib.utils.functions as func

frs_array = []
powers_array = []

for i in search.dfResults.index:
    tmp = search.dfResults.loc[i, 'exc']
    frs, powers = func.getPowerSpectrum(
        tmp[0,:],
        wc.params["dt"],
    )
    search.dfResults.loc[i, 'max_power'] = max(powers)
    index_of_maximum = np.where(powers == max(powers))
    search.dfResults.loc[i, 'freq_max_power'] = frs[index_of_maximum]
# Out:
# /Users/pamirozsuna/opt/anaconda3/lib/python3.7/site-packages/scipy/signal/spectral.py:1969: UserWarning: nperseg = 10000 is greater than input length  = 2000, using nperseg = 2000
#   .format(nperseg, input_length))

# %%
plt.imshow(search.dfResults.pivot_table(values='max_exc', index = 'c_excinh', columns='exc_ext'), \
           extent = [min(search.dfResults.c_excinh), max(search.dfResults.c_excinh),
                     min(search.dfResults.exc_ext), max(search.dfResults.exc_ext)], origin='lower')
plt.colorbar(label='Maximum Excitatory Activity')
plt.xlabel("Input to c_excinh")
plt.ylabel("Input to exc_ext")
plt.savefig('max_exc_detailed.png', dpi=500)

# %%
plt.imshow(search.dfResults.pivot_table(values='freq_max_power', index = 'c_excinh', columns='exc_ext'), \
           extent = [min(search.dfResults.c_excinh), max(search.dfResults.c_excinh),
                     min(search.dfResults.exc_ext), max(search.dfResults.exc_ext)], origin='lower')
plt.colorbar(label='Frequency of Maximum Power')
plt.xlabel("Input to c_excinh")
plt.ylabel("Input to exc_ext")
plt.savefig('freq_max_power_detailed.png', dpi=500)

# %%
plt.imshow(search.dfResults.pivot_table(values='max_power', index = 'c_excinh', columns='exc_ext'), \
           extent = [min(search.dfResults.c_excinh), max(search.dfResults.c_excinh),
                     min(search.dfResults.exc_ext), max(search.dfResults.exc_ext)], origin='lower')
plt.colorbar(label='Maximum Power')
plt.xlabel("Input to c_excinh")
plt.ylabel("Input to exc_ext")
plt.savefig('max_power_detailed.png', dpi=500)

# %%
search.dfResults
# Out:
#       exc_ext   c_excinh                                                  t  \
# 0         0.7   9.300000  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 1         0.7   9.416327  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 2         0.7   9.532653  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 3         0.7   9.648980  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 4         0.7   9.765306  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# ...       ...        ...                                                ...
# 2495      2.6  14.534694  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 2496      2.6  14.651020  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 2497      2.6  14.767347  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 2498      2.6  14.883673  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
# 2499      2.6  15.000000  [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.60...
#
#                                                     exc   max_exc  max_power  \
# 0     [[0.008562675939734024, 0.009444283320958296, ...  0.472086   0.016880
# 1     [[0.008562675939734024, 0.009444274663356164, ...  0.470434   0.017100
# 2     [[0.008562675939734024, 0.009444265994489873, ...  0.468718   0.015425
# 3     [[0.008562675939734024, 0.009444257314345202, ...  0.466955   0.014699
# 4     [[0.008562675939734024, 0.009444248622907917, ...  0.465142   0.014637
# ...                                                 ...       ...        ...
# 2495  [[0.021264307528578254, 0.03714868718455579, 0...  0.485451   0.004546
# 2496  [[0.021264307528578254, 0.0371486130283203, 0....  0.485311   0.006377
# 2497  [[0.021264307528578254, 0.03714853877531865, 0...  0.485174   0.006960
# 2498  [[0.021264307528578254, 0.03714846442542792, 0...  0.485041   0.006640
# 2499  [[0.021264307528578254, 0.03714838997852506, 0...  0.484912   0.006721
#
#       freq_max_power
# 0               35.0
# 1               30.0
# 2               30.0
# 3               35.0
# 4               35.0
# ...              ...
# 2495            40.0
# 2496            40.0
# 2497            40.0
# 2498            40.0
# 2499            45.0
#
# [2500 rows x 7 columns]

# %%
max_value = 0
max_index = 0
for i in search.dfResults.index:
    if search.dfResults.loc[i, 'freq_max_power'] >= 37 and search.dfResults.loc[i, 'freq_max_power'] <= 42:
        if max_value < search.dfResults.loc[i, 'max_power']:
            max_value = search.dfResults.loc[i, 'max_power']
            max_index = i

print(search.dfResults.loc[max_index, 'freq_max_power'])
print(search.dfResults.loc[max_index, 'max_power'])
print(search.dfResults.loc[max_index, 'c_excinh'])
print(search.dfResults.loc[max_index, 'exc_ext'])
# Out:
# 40.0
# 0.02312313927435522
# 9.76530612244898
# 0.8551020408163265

# %%
min_value = float("inf")
min_index = 0
for i in search.dfResults.index:
    if search.dfResults.loc[i, 'freq_max_power'] >= 37 and search.dfResults.loc[i, 'freq_max_power'] <= 42:
        if min_value > search.dfResults.loc[i, 'max_power']:
            min_value = search.dfResults.loc[i, 'max_power']
            min_index = i

print(search.dfResults.loc[min_index, 'freq_max_power'])
print(search.dfResults.loc[min_index, 'max_power'])
print(search.dfResults.loc[min_index, 'c_excinh'])
print(search.dfResults.loc[min_index, 'exc_ext'])
# Out:
# 40.0
# 9.993022992789527e-08
# 13.022448979591836
# 2.406122448979592
